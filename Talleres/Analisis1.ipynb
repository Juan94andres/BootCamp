# %%
import pandas as pd
Tdesempeno=pd.read_csv("Resultados_de_la_Medici_n_del_Desempe_o_Institucional (1).csv", sep=",",encoding="utf-8")
type(Tdesempeno)
# Out:
# pandas.core.frame.DataFrame

# %%
Tdesempeno
# Out:
#                                              CODIGO_SIGEP  \
# 0       2,MINISTERIO DE RELACIONES EXTERIORES,MINISTER...
# 1       4,MINISTERIO DE HACIENDA Y CRÉDITO PÚBLICO,MIN...
# 2       5,MINISTERIO DE DEFENSA NACIONAL,MINISTERIO,NA...
# 3       6,MINISTERIO DE AGRICULTURA Y DESARROLLO RURAL...
# 4       9,MINISTERIO DE MINAS Y ENERGÍA,MINISTERIO,NAC...
# ...                                                   ...
# 468596                                               9889
# 468597                                               9889
# 468598                                               9889
# 468599                                               9889
# 468600                                               9889
#
#                                                   ENTIDAD NATURALEZA_JURIDICA  \
# 0                                                     NaN                 NaN
# 1                                                     NaN                 NaN
# ...

# %%
Tdesempeno.head(2)
# Out:
#                                         CODIGO_SIGEP ENTIDAD  \
# 0  2,MINISTERIO DE RELACIONES EXTERIORES,MINISTER...     NaN
# 1  4,MINISTERIO DE HACIENDA Y CRÉDITO PÚBLICO,MIN...     NaN
#
#   NATURALEZA_JURIDICA ORDEN SECTOR  ID_MUNICIPIO MUNICIPIO  GRUPOPAR  \
# 0                 NaN   NaN    NaN           NaN       NaN       NaN
# 1                 NaN   NaN    NaN           NaN       NaN       NaN
#
#   ID_INDICE INDICE  PUNTAJE_ENTIDAD  VIGENCIA  PROMEDIO_GRUPO_PAR  \
# 0       NaN    NaN              NaN       NaN                 NaN
# 1       NaN    NaN              NaN       NaN                 NaN
#
#    MAXIMO_GRUPO_PAR  MINIMO_GRUPO_PAR  QUINTIL_GRUPO_PAR  PERCENTIL_GRUPO_PAR
# 0               NaN               NaN                NaN                  NaN
# 1               NaN               NaN                NaN                  NaN

# %%
Tdesempeno.info()
Tdesempeno.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468601 entries, 0 to 468600
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   CODIGO_SIGEP         468601 non-null  object
#  1   ENTIDAD              413805 non-null  object
#  2   NATURALEZA_JURIDICA  413668 non-null  object
#  3   ORDEN                413805 non-null  object
#  4   SECTOR               413805 non-null  object
#  5   ID_MUNICIPIO         413805 non-null  float64
#  6   MUNICIPIO            413575 non-null  object
#  7   GRUPOPAR             413805 non-null  float64
#  8   ID_INDICE            413805 non-null  object
#  9   INDICE               413805 non-null  object
#  10  PUNTAJE_ENTIDAD      413805 non-null  float64
#  11  VIGENCIA             413805 non-null  float64
#  12  PROMEDIO_GRUPO_PAR   413805 non-null  float64
#  13  MAXIMO_GRUPO_PAR     413805 non-null  float64
# ...

# %%
Tdesempeno.shape
# Out:
# (468601, 17)

# %%
Tdesempeno.index
# Out:
# RangeIndex(start=0, stop=468601, step=1)

# %%
Tdesempeno["SECTOR"].unique()
Tdesempeno["SECTOR"].value_counts()
# Out:
# SECTOR
# NO APLICA                                             397761
# AMBIENTE Y DESARROLLO SOSTENIBLE                        2800
# EDUCACIÓN                                               2467
# HACIENDA Y CRÉDITO PÚBLICO                              2448
# DEFENSA                                                 1485
# SALUD Y PROTECCIÓN SOCIAL                                953
# MINAS Y ENERGÍA                                          726
# TECNOLOGÍAS DE LA INFORMACIÓN Y LAS COMUNICACIONES       694
# INTERIOR                                                 590
# TRABAJO                                                  541
# TRANSPORTE                                               539
# PRESIDENCIA DE LA REPÚBLICA                              533
# JUSTICIA Y DEL DERECHO                                   489
# CULTURA                                                  360
# INCLUSIÓN SOCIAL Y RECONCILIACIÓN                        357
# ...

# %%
Columnas=["SECTOR","PUNTAJE_ENTIDAD"]
Tdesempeno[Columnas]
# Out:
#            SECTOR  PUNTAJE_ENTIDAD
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN
# ...           ...              ...
# 468596  NO APLICA           4865.0
# 468597  NO APLICA         577903.0
# 468598  NO APLICA         513531.0
# 468599  NO APLICA         515971.0
# 468600  NO APLICA         513134.0
#
# [468601 rows x 2 columns]
